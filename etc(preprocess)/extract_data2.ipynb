# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Rreading train dataset
file_path = "../data/train.csv"
raw_data = pd.read_csv(file_path)
print("Data points count: ", raw_data['id'].count())
raw_data.head()
# Out:
# Data points count:  7613
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data_1 = raw_data[raw_data["target"]==1]
data_1
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [3271 rows x 5 columns]

# %%
data1 = data_1.sample(n=2711)
data1
# Out:
#         id            keyword                        location  \
# 2009  2885             damage    261 5th Avenue New York, NY
# 4709  6695          landslide                             NaN
# 4271  6069        heat%20wave                             USA
# 3061  4392         earthquake                  Global Edition
# 3568  5099             famine                       Tampa, FL
# ...    ...                ...                             ...
# 6457  9238  suicide%20bombing                             NaN
# 2418  3477           derailed                              US
# 461    665             attack                     Bellevue NE
# 2374  3413             derail  Washington, Krasnodar (Russia)
# 6809  9755            tragedy                         Jamaica
#
#                                                    text  target
# 2009  Does homeowners insurance cover water damage? ...       1
# 4709  Landslide kills three near Venice after heavyå...       1
# 4271  Heat wave in WB heavy losses and no compensati...       1
# 3061  #earthquake (EMSC): MD 2.9 OFF COAST OF NORTHE...       1
# 3568  UPDATE 1-Russian 'food crematoria' provoke out...       1
# ...                                                 ...     ...
# 6457  Remembering Mordechai Yehuda Friedman 24 of Ra...       1
# 2418  Breakfast links: Work from home: Derailed: An ...       1
# 461   New post from @darkreading http://t.co/8eIJDXA...       1
# 2374  Dr. Gridlock: HereÛªs what may have caused a ...       1
# 6809  Rt hirochii0: There is no country that making ...       1
#
# [2711 rows x 5 columns]

# %%
data_2 = raw_data[raw_data["target"]==0]
data_2
# Out:
#          id  keyword location  \
# 15       23      NaN      NaN
# 16       24      NaN      NaN
# 17       25      NaN      NaN
# 18       26      NaN      NaN
# 19       28      NaN      NaN
# ...     ...      ...      ...
# 7581  10833  wrecked  Lincoln
# 7582  10834  wrecked      NaN
# 7584  10837      NaN      NaN
# 7587  10841      NaN      NaN
# 7593  10848      NaN      NaN
#
#                                                    text  target
# 15                                       What's up man?       0
# 16                                        I love fruits       0
# 17                                     Summer is lovely       0
# 18                                    My car is so fast       0
# 19                         What a goooooooaaaaaal!!!!!!       0
# ...                                                 ...     ...
# 7581  @engineshed Great atmosphere at the British Li...       0
# 7582  Cramer: Iger's 3 words that wrecked Disney's s...       0
# 7584  These boxes are ready to explode! Exploding Ki...       0
# 7587                                 Sirens everywhere!       0
# 7593  I just heard a really loud bang and everyone i...       0
#
# [4342 rows x 5 columns]

# %%
data2 = data_2.sample(n=2711)
data2
# Out:
#         id            keyword                  location  \
# 2979  4276           drowning     University of Chicago
# 5667  8087             rescue                       NaN
# 5117  7297  nuclear%20reactor                       NaN
# 2727  3917         devastated                       NaN
# 1643  2373          collapsed                  (he/him)
# ...    ...                ...                       ...
# 3417  4890            explode                Whitby, ON
# 3696  5259           fatality                  Honduras
# 4992  7122           military                       NaN
# 4606  6549             injury  Cambridge, Massachusetts
# 1898  2729            crushed         Ontario, Canada.
#
#                                                    text  target
# 2979  Epilepsy claims another. Common and still a ch...       0
# 5667  Last Chance Animal Rescue has 3 new posts. htt...       0
# 5117  Finnish Nuclear Plant to Move Ahead After Fina...       0
# 2727         Good for her lol\r\nhttp://t.co/K9cD0EFVuT       0
# 1643     @indiepopmom I CANT BREATHE MY LUNGS COLLAPSED       0
# ...                                                 ...     ...
# 3417                          I'm about to explode ????       0
# 3696                                      Fatality ????       0
# 4992  Online infantryman experimental military train...       0
# 4606  Greg Garza not in the 18 for Atlas tonight vs ...       0
# 1898  Jesus Christ that ball was fucking crushed!! #...       0
#
# [2711 rows x 5 columns]

# %%
# 드리프트 전 데이터
# 초기 실험 데이터 재난:20% 평시: 80%
# 1000개 4342개
train1 = pd.concat([data1, data2])
train1 = train1.sample(n=5422)
train1
# Out:
#          id            keyword           location  \
# 850    1230              blood                NaN
# 5127   7312  nuclear%20reactor                NaN
# 3407   4877            explode          Australia
# 3083   4425        electrocute                NaN
# 2208   3163             deluge                NaN
# ...     ...                ...                ...
# 2419   3478           derailed        åø\_(?)_/åø
# 1048   1515        body%20bags  In the Shadows...
# 776    1123          blew%20up                NaN
# 7245  10375            weapons    Rocky Mountains
# 3998   5677             floods                NaN
#
#                                                    text  target
# 850   @Chief__CG nah young blood that cook is gone I...       0
# 5127  @RobertHarding @RepJohnKatko Crazy to use the ...       1
# 3407  It's cold and my head wants to explode.. The j...       0
# 3083  She says that she'd love to come help but\r\nT...       0
# 2208  A deluge of eulogies  for #CecilTheLion on my ...       0
# ...                                                 ...     ...
# 2419  On the eve of Jon Stewart leaving The Daily Sh...       1
# 1048  @Limpar33 sweeping legs? Or putting people in ...       0
# 776   Ye did the same thing to Big Sean and he still...       0
# 7245  WWII Memories Plus Lessons of Hiroshima We Sti...       1
# 3998  69 Dead Due to Floods in Myanmar: Naypyidaw Au...       1
#
# [5422 rows x 5 columns]

# %%
# Plotting target value counts
plt.figure(figsize=(10,8))
ax = train1['target'].value_counts().sort_values().plot(kind="bar")
ax.grid(axis="y")
plt.suptitle("Target Value Counts", fontsize=20)
# plt.show()
# Out:
# Text(0.5, 0.98, 'Target Value Counts')

# %%
train1.to_csv('../data/after_train.csv', index=False)
